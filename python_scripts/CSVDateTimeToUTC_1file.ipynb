# %%
# package import

import pandas as pd

# %%
# this script is a rough draft for the data processing steps. Kindly disregard

df = pd.read_csv('process_data_12.csv')
df.head()
# Out:
#        event_timestamp  tag__id        tag__name  \
# 0  12/05/2022 09:03:10    35827   L_R1SDW_SPDREF
# 1  12/05/2022 09:03:10    83540   L_R1_CNT_PASS0
# 2  12/05/2022 09:03:10    83539    L_R1SD_DS_CUR
# 3  12/05/2022 09:03:10    83538    L_R1SD_WS_CUR
# 4  12/05/2022 09:03:10    83537  L_R1SDLS_SPDFBK
#
#                                 tag__desc  tag__value      tag__unit  \
# 0  R1 Screw Down WS Speed Reference (mps)         0.0  Not Available
# 1                    R1 CONTROL PASS ZERO         1.0  Not Available
# 2            R1 SCREW DOWN DS CURRENT (%)         0.0  Not Available
# 3            R1 SCREW DOWN WS CURRENT (%)         0.0  Not Available
# 4        R1 SCREW DOWN LS SPEED FBK (MPS)         0.0  Not Available
#
#       device_identifier
# 0  R1SD_ProcessDatabase
# 1  R1SD_ProcessDatabase
# 2  R1SD_ProcessDatabase
# 3  R1SD_ProcessDatabase
# 4  R1SD_ProcessDatabase

# %%
df['event_timestamp'] = pd.to_datetime(df['event_timestamp'])
df['event_timestamp'] = df['event_timestamp'] - pd.Timedelta(hours = 5, minutes = 30)
df['event_timestamp'].head()
# Out:
# 0   2022-12-04 22:03:10
# 1   2022-12-04 22:03:10
# 2   2022-12-04 22:03:10
# 3   2022-12-04 22:03:10
# 4   2022-12-04 22:03:10
# Name: event_timestamp, dtype: datetime64[ns]

# %%
df['event_timestamp'] = df['event_timestamp'].dt.strftime('%d-%m-%y %H:%M:%S')
df['event_timestamp'].head()
# Out:
# 0    05-12-22 03:33:10
# 1    05-12-22 03:33:10
# 2    05-12-22 03:33:10
# 3    05-12-22 03:33:10
# 4    05-12-22 03:33:10
# Name: event_timestamp, dtype: object

# %%
df.head()
# Out:
#          event_timestamp  tag__id        tag__name  \
# 0      05-12-22 03:33:10    35827   L_R1SDW_SPDREF
# 1      05-12-22 03:33:10    83540   L_R1_CNT_PASS0
# 2      05-12-22 03:33:10    83539    L_R1SD_DS_CUR
# 3      05-12-22 03:33:10    83538    L_R1SD_WS_CUR
# 4      05-12-22 03:33:10    83537  L_R1SDLS_SPDFBK
# ...                  ...      ...              ...
# 34483  05-12-22 18:27:10    35830   L_R1SDW_SPDFBK
# 34484  05-12-22 18:27:10    35829   L_R1SDL_SPDREF
# 34485  05-12-22 18:27:10    35827   L_R1SDW_SPDREF
# 34486  05-12-22 18:27:10    83531    L_R1SD_DS_GAP
# 34487  05-12-22 18:27:10    83540   L_R1_CNT_PASS0
#
#                                     tag__desc  tag__value      tag__unit  \
# 0      R1 Screw Down WS Speed Reference (mps)    0.000000  Not Available
# 1                        R1 CONTROL PASS ZERO    1.000000  Not Available
# 2                R1 SCREW DOWN DS CURRENT (%)    0.000000  Not Available
# ...
